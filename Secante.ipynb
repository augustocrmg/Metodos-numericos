# %%
import numpy as np
import matplotlib.pyplot as plt
from math import e

# %%
# Matrix de valores usados para plotas os pontos da função 
x = np.linspace(-2,2,20)
# Função usada para determinar os pontos
y = (x**2)-(e**(-x))

# %%
# Plot da função y
# Recomenda-se fortemente basear-se no desenho da função para pensar nos
#   valores a e b usados 
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('zero')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
plt.grid(True)
plt.plot(x,y, 'r')
plt.show()

# %%
a = float(-2)
b = float(2)
nIter = int(10000)
tolerancia = float(0.000001)

# %%
def secante(f,a,b,N):
    '''Approximate solution of f(x)=0 on interval [a,b] by the secant method.

    Parâmetros
    ----------
    f : função
        Função que nós estamos tentando aproximar o resultado f(x)=0.
    a,b : Pontos do intervalo
        Representam o intervalo pelo qual nós estamos procurando o resultado. A função retorna
        None se f(a)*f(b) >= 0, pois não há solução garantida. 
    N : numero
        Número de iterções que será implementado

    Returns
    -------
    m_N : numero
        A interceptação x da linha secante no enésimo intervalo
            m_n = a_n - f(a_n)*(b_n - a_n)/(f(b_n) - f(a_n))
        O intervalo inicial [a_0,b_0] é dado por [a,b]. Se f(m_n) == 0
        para alguma interceptação m_n então a função retornara a solução.
        Se todos os sinais de valores f(a_n), f(b_n) e f(m_n) são os mesmos em qualquer 
        iteração, o método secante falha e retorna None.

    Exemplos
    --------
    >>> f = lambda x: x**2 - x - 1
    >>> secant(f,1,2,5)
    1.6180257510729614
    '''
    if f(a)*f(b) >= 0:
        print("O método secante falhou.")
        return None
    a_n = a
    b_n = b
    for n in range(1,N+1):
        m_n = a_n - f(a_n)*(b_n - a_n)/(f(b_n) - f(a_n))
        print(f'Iteração = {n}\nX(i+1) = {a_n} - ({f(a_n)}*{(b_n - a_n)})/({f(b_n)} - {f(a_n)})\nX(i+1) = {m_n}')
        f_m_n = f(m_n)
        if f(a_n)*f_m_n < 0:
            a_n = a_n
            b_n = m_n
        elif f(b_n)*f_m_n < 0:
            a_n = m_n
            b_n = b_n
        elif f_m_n == 0:
            print("Solução exata = ")
            return m_n
        else:
            print("O método secante falhou.")
            return None
    return a_n - f(a_n)*(b_n - a_n)/(f(b_n) - f(a_n))

# %%
f = lambda z:(z**2)-(e**(-z))
approx = secante(f,a,b,nIter)
print(approx)
# Out:
# Iteração = 1
# X(i+1) = -2.0 - (-3.3890560989306495*4.0)/(3.864664716763387 - -3.3890560989306495)
# X(i+1) = -0.13113507671916946
# Iteração = 2
# X(i+1) = -0.13113507671916946 - (-1.1229253664739411*2.1311350767191692)/(3.864664716763387 - -1.1229253664739411)
# X(i+1) = 0.3486769361151
# Iteração = 3
# X(i+1) = 0.3486769361151 - (-0.5840454483513892*1.6513230638849001)/(3.864664716763387 - -0.5840454483513892)
# X(i+1) = 0.5654695981281271
# Iteração = 4
# X(i+1) = 0.5654695981281271 - (-0.2483374421475994*1.4345304018718728)/(3.864664716763387 - -0.2483374421475994)
# X(i+1) = 0.6520845807903666
# Iteração = 5
# X(i+1) = 0.6520845807903666 - (-0.09574436313976864*1.3479154192096334)/(3.864664716763387 - -0.09574436313976864)
# X(i+1) = 0.6846709375971378
# Iteração = 6
# X(i+1) = 0.6846709375971378 - (-0.035481841221844335*1.3153290624028622)/(3.864664716763387 - -0.035481841221844335)
# X(i+1) = 0.6966372307229954
# Iteração = 7
# X(i+1) = 0.6966372307229954 - (-0.012954585262163032*1.3033627692770047)/(3.864664716763387 - -0.012954585262163032)
# X(i+1) = 0.7009915839503243
# Iteração = 8
# X(i+1) = 0.7009915839503243 - (-0.004703941055298144*1.2990084160496758)/(3.864664716763387 - -0.004703941055298144)
# X(i+1) = 0.702570771554247
# Iteração = 9
# X(i+1) = 0.702570771554247 - (-0.0017046469035448264*1.2974292284457531)/(3.864664716763387 - -0.0017046469035448264)
# X(i+1) = 0.7031427962391159
# Iteração = 10
# X(i+1) = 0.7031427962391159 - (-0.0006172953244330537*1.296857203760884)/(3.864664716763387 - -0.0006172953244330537)
# X(i+1) = 0.703349907618269
# Iteração = 11
# X(i+1) = 0.703349907618269 - (-0.00022347955440565892*1.296650092381731)/(3.864664716763387 - -0.00022347955440565892)
# X(i+1) = 0.7034248838582393
# Iteração = 12
# X(i+1) = 0.7034248838582393 - (-8.089867762939296e-05*1.2965751161417607)/(3.864664716763387 - -8.089867762939296e-05)
# X(i+1) = 0.7034520243799658
# Iteração = 13
# X(i+1) = 0.7034520243799658 - (-2.928398258167375e-05*1.2965479756200342)/(3.864664716763387 - -2.928398258167375e-05)
# X(i+1) = 0.7034618487252637
# Iteração = 14
# X(i+1) = 0.7034618487252637 - (-1.0600185374964877e-05*1.2965381512747363)/(3.864664716763387 - -1.0600185374964877e-05)
# X(i+1) = 0.7034654049217414
# Iteração = 15
# X(i+1) = 0.7034654049217414 - (-3.837026751274397e-06*1.2965345950782585)/(3.864664716763387 - -3.837026751274397e-06)
# X(i+1) = 0.703466692182953
# Iteração = 16
# X(i+1) = 0.703466692182953 - (-1.3889144196976844e-06*1.2965333078170471)/(3.864664716763387 - -1.3889144196976844e-06)
# X(i+1) = 0.7034671581413974
# Iteração = 17
# X(i+1) = 0.7034671581413974 - (-5.027544121016803e-07*1.2965328418586026)/(3.864664716763387 - -5.027544121016803e-07)
# X(i+1) = 0.7034673268073929
# Iteração = 18
# X(i+1) = 0.7034673268073929 - (-1.819852551432355e-07*1.296532673192607)/(3.864664716763387 - -1.819852551432355e-07)
# X(i+1) = 0.7034673878605076
# Iteração = 19
# X(i+1) = 0.7034673878605076 - (-6.587437073601876e-08*1.2965326121394924)/(3.864664716763387 - -6.587437073601876e-08)
# X(i+1) = 0.7034674099602949
# Iteração = 20
# X(i+1) = 0.7034674099602949 - (-2.3844968111141895e-08*1.2965325900397051)/(3.864664716763387 - -2.3844968111141895e-08)
# X(i+1) = 0.7034674179598965
# Iteração = 21
# X(i+1) = 0.7034674179598965 - (-8.631315717710919e-09*1.2965325820401035)/(3.864664716763387 - -8.631315717710919e-09)
# X(i+1) = 0.7034674208555636
# Iteração = 22
# X(i+1) = 0.7034674208555636 - (-3.12433257043665e-09*1.2965325791444364)/(3.864664716763387 - -3.12433257043665e-09)
# X(i+1) = 0.7034674219037267
# Iteração = 23
# X(i+1) = 0.7034674219037267 - (-1.1309345682164462e-09*1.2965325780962733)/(3.864664716763387 - -1.1309345682164462e-09)
# X(i+1) = 0.703467422283137
# Iteração = 24
# X(i+1) = 0.703467422283137 - (-4.0937164769161427e-10*1.296532577716863)/(3.864664716763387 - -4.0937164769161427e-10)
# X(i+1) = 0.7034674224204746
# Iteração = 25
# X(i+1) = 0.7034674224204746 - (-1.4818285487550042e-10*1.2965325775795256)/(3.864664716763387 - -1.4818285487550042e-10)
# X(i+1) = 0.7034674224701875
# Iteração = 26
# X(i+1) = 0.7034674224701875 - (-5.363881561137873e-11*1.2965325775298124)/(3.864664716763387 - -5.363881561137873e-11)
# X(i+1) = 0.7034674224881824
# Iteração = 27
# X(i+1) = 0.7034674224881824 - (-1.9416024343854588e-11*1.2965325775118175)/(3.864664716763387 - -1.9416024343854588e-11)
# X(i+1) = 0.7034674224946962
# Iteração = 28
# X(i+1) = 0.7034674224946962 - (-7.0280448127846284e-12*1.2965325775053038)/(3.864664716763387 - -7.0280448127846284e-12)
# X(i+1) = 0.703467422497054
# Iteração = 29
# X(i+1) = 0.703467422497054 - (-2.544020549777315e-12*1.296532577502946)/(3.864664716763387 - -2.544020549777315e-12)
# X(i+1) = 0.7034674224979074
# Iteração = 30
# X(i+1) = 0.7034674224979074 - (-9.209855100777986e-13*1.2965325775020926)/(3.864664716763387 - -9.209855100777986e-13)
# X(i+1) = 0.7034674224982164
# Iteração = 31
# X(i+1) = 0.7034674224982164 - (-3.333999742949345e-13*1.2965325775017837)/(3.864664716763387 - -3.333999742949345e-13)
# X(i+1) = 0.7034674224983282
# Iteração = 32
# X(i+1) = 0.7034674224983282 - (-1.2073675392798577e-13*1.2965325775016718)/(3.864664716763387 - -1.2073675392798577e-13)
# X(i+1) = 0.7034674224983687
# Iteração = 33
# X(i+1) = 0.7034674224983687 - (-4.368727601899991e-14*1.2965325775016314)/(3.864664716763387 - -4.368727601899991e-14)
# X(i+1) = 0.7034674224983833
# Iteração = 34
# X(i+1) = 0.7034674224983833 - (-1.582067810090848e-14*1.2965325775016168)/(3.864664716763387 - -1.582067810090848e-14)
# X(i+1) = 0.7034674224983887
# Iteração = 35
# X(i+1) = 0.7034674224983887 - (-5.717648576819556e-15*1.2965325775016114)/(3.864664716763387 - -5.717648576819556e-15)
# X(i+1) = 0.7034674224983906
# Iteração = 36
# X(i+1) = 0.7034674224983906 - (-2.1094237467877974e-15*1.2965325775016094)/(3.864664716763387 - -2.1094237467877974e-15)
# X(i+1) = 0.7034674224983912
# Iteração = 37
# X(i+1) = 0.7034674224983912 - (-8.326672684688674e-16*1.2965325775016088)/(3.864664716763387 - -8.326672684688674e-16)
# X(i+1) = 0.7034674224983916
# Iteração = 38
# X(i+1) = 0.7034674224983916 - (-2.220446049250313e-16*1.2965325775016083)/(3.864664716763387 - -2.220446049250313e-16)
# X(i+1) = 0.7034674224983917
# Solução exata =
# 0.7034674224983917
