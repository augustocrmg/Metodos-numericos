# %%
import numpy as np
import matplotlib.pyplot as plt
from math import e

# %%
# 100 linearly spaced numbers
x = np.linspace(-5,5,100)
y = (x**2)-(e**(-x))

# %%
# the function, which is y = x^2 here
def function(x):
    y = (x**2)-(e**(-x)) 
    return y

# %%
# setting the axes at the centre
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('zero')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
plt.grid(True)
# plot the function
plt.plot(x,y, 'r')
# show the plot
plt.show()

# %%
def newton(f,Df,x0,epsilon,max_iter):
    '''Aproxima a solução de f(x)=0 pelo método de Newton.

    Parameters
    ----------
    f : função
        Função para qual se está procurando a solução f(x)=0.
    Df : função
        Derivada de f(x).
    x0 : número
        Suposição inicial para uma solução f(x)=0.
    epsilon : número
        O critério de parada é abs(f(x)) < epsilon.
    max_iter : inteiro
        Número máximo de iterações do método de Newton. 

    Returns
    -------
    xn : numero
        Implementação do método de Newton: compute a aproximação linear
        de f(x) em xn e encontre x interceptado pela fórmula
            x = xn - f(xn)/Df(xn)
        Continue enquanto abs(f(xn)) < epsilon e retorna xn.
        Se Df(xn) == 0, retorna None. Se o número de iterações
        exceder max_iter, então retorna None.

    Exemplos
    --------
    >>> f = lambda x: x**2 - x - 1
    >>> Df = lambda x: 2*x - 1
    >>> newton(f,Df,1,1e-8,10)
    A solução foi encontrada após 5 iterações.
    1.618033988749989
    '''
    xn = x0
    for n in range(0,max_iter):
        print(f'iteração = {n+1}')
        fxn = f(xn)
        print(f'f(x{n+1}) = {fxn}')
        if abs(fxn) < epsilon:
            print(f'A solução foi encontrada após {n} iterações.')
            #return xn
        Dfxn = Df(xn)
        print(f'f`(x{n+1}) = {Dfxn}')
        if Dfxn == 0:
            print('Derivada zero. Nenhuma solução encontrada.')
            return None
        print(f'x{n+2} = {xn} - ({fxn}/{Dfxn})')
        xn = xn - fxn/Dfxn
        print(f'x{n+2} = {xn}')
        print('\n')
    print('Excede o número máximo de iterações. Nenhuma solução encontrada.')
    return None

# %%
p = lambda z:(z**2)-(e**(-z))
Dp = lambda z:(2*z)+(e**(-z))
approx = newton(p,Dp,1,1e-10,10000)
print(approx)
# Out:
# iteração = 1
# f(x1) = 0.6321205588285577
# f`(x1) = 2.3678794411714423
# x2 = 1 - (0.6321205588285577/2.3678794411714423)
# x2 = 0.7330436052454454
#
#
# iteração = 2
# f(x2) = 0.05690844800402539
# f`(x2) = 1.946531689678106
# x3 = 0.7330436052454454 - (0.05690844800402539/1.946531689678106)
# x3 = 0.703807786324133
#
#
# iteração = 3
# f(x3) = 0.000647391538746489
# f`(x3) = 1.902313581199996
# x4 = 0.703807786324133 - (0.000647391538746489/1.902313581199996)
# x4 = 0.7034674683317975
#
#
# iteração = 4
# f(x4) = 8.716603056013739e-08
# f`(x4) = 1.901801328498713
# x5 = 0.7034674683317975 - (8.716603056013739e-08/1.901801328498713)
# x5 = 0.7034674224983924
#
#
# iteração = 5
# f(x5) = 1.4988010832439613e-15
# A solução foi encontrada após 4 iterações.
# f`(x5) = 1.9018012595133151
# x6 = 0.7034674224983924 - (1.4988010832439613e-15/1.9018012595133151)
# x6 = 0.7034674224983917
#
#
# iteração = 6
# f(x6) = 0.0
# A solução foi encontrada após 5 iterações.
# f`(x6) = 1.901801259513314
# x7 = 0.7034674224983917 - (0.0/1.901801259513314)
# x7 = 0.7034674224983917
#
#
# iteração = 7
# f(x7) = 0.0
# A solução foi encontrada após 6 iterações.
# f`(x7) = 1.901801259513314
# x8 = 0.7034674224983917 - (0.0/1.901801259513314)
# x8 = 0.7034674224983917
#
#
# iteração = 8
# f(x8) = 0.0
# A solução foi encontrada após 7 iterações.
# f`(x8) = 1.901801259513314
# x9 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9 = 0.7034674224983917
#
#
# iteração = 9
# f(x9) = 0.0
# A solução foi encontrada após 8 iterações.
# f`(x9) = 1.901801259513314
# x10 = 0.7034674224983917 - (0.0/1.901801259513314)
# x10 = 0.7034674224983917
#
#
# iteração = 10
# f(x10) = 0.0
# A solução foi encontrada após 9 iterações.
# f`(x10) = 1.901801259513314
# x11 = 0.7034674224983917 - (0.0/1.901801259513314)
# x11 = 0.7034674224983917
#
#
# iteração = 11
# f(x11) = 0.0
# A solução foi encontrada após 10 iterações.
# f`(x11) = 1.901801259513314
# x12 = 0.7034674224983917 - (0.0/1.901801259513314)
# x12 = 0.7034674224983917
#
#
# iteração = 12
# f(x12) = 0.0
# A solução foi encontrada após 11 iterações.
# f`(x12) = 1.901801259513314
# x13 = 0.7034674224983917 - (0.0/1.901801259513314)
# x13 = 0.7034674224983917
#
#
# iteração = 13
# f(x13) = 0.0
# A solução foi encontrada após 12 iterações.
# f`(x13) = 1.901801259513314
# x14 = 0.7034674224983917 - (0.0/1.901801259513314)
# x14 = 0.7034674224983917
#
#
# iteração = 14
# f(x14) = 0.0
# A solução foi encontrada após 13 iterações.
# f`(x14) = 1.901801259513314
# x15 = 0.7034674224983917 - (0.0/1.901801259513314)
# x15 = 0.7034674224983917
#
#
# iteração = 15
# f(x15) = 0.0
# A solução foi encontrada após 14 iterações.
# f`(x15) = 1.901801259513314
# x16 = 0.7034674224983917 - (0.0/1.901801259513314)
# x16 = 0.7034674224983917
#
#
# iteração = 16
# f(x16) = 0.0
# A solução foi encontrada após 15 iterações.
# f`(x16) = 1.901801259513314
# x17 = 0.7034674224983917 - (0.0/1.901801259513314)
# x17 = 0.7034674224983917
#
#
# iteração = 17
# f(x17) = 0.0
# A solução foi encontrada após 16 iterações.
# f`(x17) = 1.901801259513314
# x18 = 0.7034674224983917 - (0.0/1.901801259513314)
# x18 = 0.7034674224983917
#
#
# iteração = 18
# f(x18) = 0.0
# A solução foi encontrada após 17 iterações.
# f`(x18) = 1.901801259513314
# x19 = 0.7034674224983917 - (0.0/1.901801259513314)
# x19 = 0.7034674224983917
#
#
# iteração = 19
# f(x19) = 0.0
# A solução foi encontrada após 18 iterações.
# f`(x19) = 1.901801259513314
# x20 = 0.7034674224983917 - (0.0/1.901801259513314)
# x20 = 0.7034674224983917
#
#
# iteração = 20
# f(x20) = 0.0
# A solução foi encontrada após 19 iterações.
# f`(x20) = 1.901801259513314
# x21 = 0.7034674224983917 - (0.0/1.901801259513314)
# x21 = 0.7034674224983917
#
#
# iteração = 21
# f(x21) = 0.0
# A solução foi encontrada após 20 iterações.
# f`(x21) = 1.901801259513314
# x22 = 0.7034674224983917 - (0.0/1.901801259513314)
# x22 = 0.7034674224983917
#
#
# iteração = 22
# f(x22) = 0.0
# A solução foi encontrada após 21 iterações.
# f`(x22) = 1.901801259513314
# x23 = 0.7034674224983917 - (0.0/1.901801259513314)
# x23 = 0.7034674224983917
#
#
# iteração = 23
# f(x23) = 0.0
# A solução foi encontrada após 22 iterações.
# f`(x23) = 1.901801259513314
# x24 = 0.7034674224983917 - (0.0/1.901801259513314)
# x24 = 0.7034674224983917
#
#
# iteração = 24
# f(x24) = 0.0
# A solução foi encontrada após 23 iterações.
# f`(x24) = 1.901801259513314
# x25 = 0.7034674224983917 - (0.0/1.901801259513314)
# x25 = 0.7034674224983917
#
#
# iteração = 25
# f(x25) = 0.0
# A solução foi encontrada após 24 iterações.
# f`(x25) = 1.901801259513314
# x26 = 0.7034674224983917 - (0.0/1.901801259513314)
# x26 = 0.7034674224983917
#
#
# iteração = 26
# f(x26) = 0.0
# A solução foi encontrada após 25 iterações.
# f`(x26) = 1.901801259513314
# x27 = 0.7034674224983917 - (0.0/1.901801259513314)
# x27 = 0.7034674224983917
#
#
# iteração = 27
# f(x27) = 0.0
# A solução foi encontrada após 26 iterações.
# f`(x27) = 1.901801259513314
# x28 = 0.7034674224983917 - (0.0/1.901801259513314)
# x28 = 0.7034674224983917
#
#
# iteração = 28
# f(x28) = 0.0
# A solução foi encontrada após 27 iterações.
# f`(x28) = 1.901801259513314
# x29 = 0.7034674224983917 - (0.0/1.901801259513314)
# x29 = 0.7034674224983917
#
#
# iteração = 29
# f(x29) = 0.0
# A solução foi encontrada após 28 iterações.
# f`(x29) = 1.901801259513314
# x30 = 0.7034674224983917 - (0.0/1.901801259513314)
# x30 = 0.7034674224983917
#
#
# iteração = 30
# f(x30) = 0.0
# A solução foi encontrada após 29 iterações.
# f`(x30) = 1.901801259513314
# x31 = 0.7034674224983917 - (0.0/1.901801259513314)
# x31 = 0.7034674224983917
#
#
# iteração = 31
# f(x31) = 0.0
# A solução foi encontrada após 30 iterações.
# f`(x31) = 1.901801259513314
# x32 = 0.7034674224983917 - (0.0/1.901801259513314)
# x32 = 0.7034674224983917
#
#
# iteração = 32
# f(x32) = 0.0
# A solução foi encontrada após 31 iterações.
# f`(x32) = 1.901801259513314
# x33 = 0.7034674224983917 - (0.0/1.901801259513314)
# x33 = 0.7034674224983917
#
#
# iteração = 33
# f(x33) = 0.0
# A solução foi encontrada após 32 iterações.
# f`(x33) = 1.901801259513314
# x34 = 0.7034674224983917 - (0.0/1.901801259513314)
# x34 = 0.7034674224983917
#
#
# iteração = 34
# f(x34) = 0.0
# A solução foi encontrada após 33 iterações.
# f`(x34) = 1.901801259513314
# x35 = 0.7034674224983917 - (0.0/1.901801259513314)
# x35 = 0.7034674224983917
#
#
# iteração = 35
# f(x35) = 0.0
# A solução foi encontrada após 34 iterações.
# f`(x35) = 1.901801259513314
# x36 = 0.7034674224983917 - (0.0/1.901801259513314)
# x36 = 0.7034674224983917
#
#
# iteração = 36
# f(x36) = 0.0
# A solução foi encontrada após 35 iterações.
# f`(x36) = 1.901801259513314
# x37 = 0.7034674224983917 - (0.0/1.901801259513314)
# x37 = 0.7034674224983917
#
#
# iteração = 37
# f(x37) = 0.0
# A solução foi encontrada após 36 iterações.
# f`(x37) = 1.901801259513314
# x38 = 0.7034674224983917 - (0.0/1.901801259513314)
# x38 = 0.7034674224983917
#
#
# iteração = 38
# f(x38) = 0.0
# A solução foi encontrada após 37 iterações.
# f`(x38) = 1.901801259513314
# x39 = 0.7034674224983917 - (0.0/1.901801259513314)
# x39 = 0.7034674224983917
#
#
# iteração = 39
# f(x39) = 0.0
# A solução foi encontrada após 38 iterações.
# f`(x39) = 1.901801259513314
# x40 = 0.7034674224983917 - (0.0/1.901801259513314)
# x40 = 0.7034674224983917
#
#
# iteração = 40
# f(x40) = 0.0
# A solução foi encontrada após 39 iterações.
# f`(x40) = 1.901801259513314
# x41 = 0.7034674224983917 - (0.0/1.901801259513314)
# x41 = 0.7034674224983917
#
#
# iteração = 41
# f(x41) = 0.0
# A solução foi encontrada após 40 iterações.
# f`(x41) = 1.901801259513314
# x42 = 0.7034674224983917 - (0.0/1.901801259513314)
# x42 = 0.7034674224983917
#
#
# iteração = 42
# f(x42) = 0.0
# A solução foi encontrada após 41 iterações.
# f`(x42) = 1.901801259513314
# x43 = 0.7034674224983917 - (0.0/1.901801259513314)
# x43 = 0.7034674224983917
#
#
# iteração = 43
# f(x43) = 0.0
# A solução foi encontrada após 42 iterações.
# f`(x43) = 1.901801259513314
# x44 = 0.7034674224983917 - (0.0/1.901801259513314)
# x44 = 0.7034674224983917
#
#
# iteração = 44
# f(x44) = 0.0
# A solução foi encontrada após 43 iterações.
# f`(x44) = 1.901801259513314
# x45 = 0.7034674224983917 - (0.0/1.901801259513314)
# x45 = 0.7034674224983917
#
#
# iteração = 45
# f(x45) = 0.0
# A solução foi encontrada após 44 iterações.
# f`(x45) = 1.901801259513314
# x46 = 0.7034674224983917 - (0.0/1.901801259513314)
# x46 = 0.7034674224983917
#
#
# iteração = 46
# f(x46) = 0.0
# A solução foi encontrada após 45 iterações.
# f`(x46) = 1.901801259513314
# x47 = 0.7034674224983917 - (0.0/1.901801259513314)
# x47 = 0.7034674224983917
#
#
# iteração = 47
# f(x47) = 0.0
# A solução foi encontrada após 46 iterações.
# f`(x47) = 1.901801259513314
# x48 = 0.7034674224983917 - (0.0/1.901801259513314)
# x48 = 0.7034674224983917
#
#
# iteração = 48
# f(x48) = 0.0
# A solução foi encontrada após 47 iterações.
# f`(x48) = 1.901801259513314
# x49 = 0.7034674224983917 - (0.0/1.901801259513314)
# x49 = 0.7034674224983917
#
#
# iteração = 49
# f(x49) = 0.0
# A solução foi encontrada após 48 iterações.
# f`(x49) = 1.901801259513314
# x50 = 0.7034674224983917 - (0.0/1.901801259513314)
# x50 = 0.7034674224983917
#
#
# iteração = 50
# f(x50) = 0.0
# A solução foi encontrada após 49 iterações.
# f`(x50) = 1.901801259513314
# x51 = 0.7034674224983917 - (0.0/1.901801259513314)
# x51 = 0.7034674224983917
#
#
# iteração = 51
# f(x51) = 0.0
# A solução foi encontrada após 50 iterações.
# f`(x51) = 1.901801259513314
# x52 = 0.7034674224983917 - (0.0/1.901801259513314)
# x52 = 0.7034674224983917
#
#
# iteração = 52
# f(x52) = 0.0
# A solução foi encontrada após 51 iterações.
# f`(x52) = 1.901801259513314
# x53 = 0.7034674224983917 - (0.0/1.901801259513314)
# x53 = 0.7034674224983917
#
#
# iteração = 53
# f(x53) = 0.0
# A solução foi encontrada após 52 iterações.
# f`(x53) = 1.901801259513314
# x54 = 0.7034674224983917 - (0.0/1.901801259513314)
# x54 = 0.7034674224983917
#
#
# iteração = 54
# f(x54) = 0.0
# A solução foi encontrada após 53 iterações.
# f`(x54) = 1.901801259513314
# x55 = 0.7034674224983917 - (0.0/1.901801259513314)
# x55 = 0.7034674224983917
#
#
# iteração = 55
# f(x55) = 0.0
# A solução foi encontrada após 54 iterações.
# f`(x55) = 1.901801259513314
# x56 = 0.7034674224983917 - (0.0/1.901801259513314)
# x56 = 0.7034674224983917
#
#
# iteração = 56
# f(x56) = 0.0
# A solução foi encontrada após 55 iterações.
# f`(x56) = 1.901801259513314
# x57 = 0.7034674224983917 - (0.0/1.901801259513314)
# x57 = 0.7034674224983917
#
#
# iteração = 57
# f(x57) = 0.0
# A solução foi encontrada após 56 iterações.
# f`(x57) = 1.901801259513314
# x58 = 0.7034674224983917 - (0.0/1.901801259513314)
# x58 = 0.7034674224983917
#
#
# iteração = 58
# f(x58) = 0.0
# A solução foi encontrada após 57 iterações.
# f`(x58) = 1.901801259513314
# x59 = 0.7034674224983917 - (0.0/1.901801259513314)
# x59 = 0.7034674224983917
#
#
# iteração = 59
# f(x59) = 0.0
# A solução foi encontrada após 58 iterações.
# f`(x59) = 1.901801259513314
# x60 = 0.7034674224983917 - (0.0/1.901801259513314)
# x60 = 0.7034674224983917
#
#
# iteração = 60
# f(x60) = 0.0
# A solução foi encontrada após 59 iterações.
# f`(x60) = 1.901801259513314
# x61 = 0.7034674224983917 - (0.0/1.901801259513314)
# x61 = 0.7034674224983917
#
#
# iteração = 61
# f(x61) = 0.0
# A solução foi encontrada após 60 iterações.
# f`(x61) = 1.901801259513314
# x62 = 0.7034674224983917 - (0.0/1.901801259513314)
# x62 = 0.7034674224983917
#
#
# iteração = 62
# f(x62) = 0.0
# A solução foi encontrada após 61 iterações.
# f`(x62) = 1.901801259513314
# x63 = 0.7034674224983917 - (0.0/1.901801259513314)
# x63 = 0.7034674224983917
#
#
# iteração = 63
# f(x63) = 0.0
# A solução foi encontrada após 62 iterações.
# f`(x63) = 1.901801259513314
# x64 = 0.7034674224983917 - (0.0/1.901801259513314)
# x64 = 0.7034674224983917
#
#
# iteração = 64
# f(x64) = 0.0
# A solução foi encontrada após 63 iterações.
# f`(x64) = 1.901801259513314
# x65 = 0.7034674224983917 - (0.0/1.901801259513314)
# x65 = 0.7034674224983917
#
#
# iteração = 65
# f(x65) = 0.0
# A solução foi encontrada após 64 iterações.
# f`(x65) = 1.901801259513314
# x66 = 0.7034674224983917 - (0.0/1.901801259513314)
# x66 = 0.7034674224983917
#
#
# iteração = 66
# f(x66) = 0.0
# A solução foi encontrada após 65 iterações.
# f`(x66) = 1.901801259513314
# x67 = 0.7034674224983917 - (0.0/1.901801259513314)
# x67 = 0.7034674224983917
#
#
# iteração = 67
# f(x67) = 0.0
# A solução foi encontrada após 66 iterações.
# f`(x67) = 1.901801259513314
# x68 = 0.7034674224983917 - (0.0/1.901801259513314)
# x68 = 0.7034674224983917
#
#
# iteração = 68
# f(x68) = 0.0
# A solução foi encontrada após 67 iterações.
# f`(x68) = 1.901801259513314
# x69 = 0.7034674224983917 - (0.0/1.901801259513314)
# x69 = 0.7034674224983917
#
#
# iteração = 69
# f(x69) = 0.0
# A solução foi encontrada após 68 iterações.
# f`(x69) = 1.901801259513314
# x70 = 0.7034674224983917 - (0.0/1.901801259513314)
# x70 = 0.7034674224983917
#
#
# iteração = 70
# f(x70) = 0.0
# A solução foi encontrada após 69 iterações.
# f`(x70) = 1.901801259513314
# x71 = 0.7034674224983917 - (0.0/1.901801259513314)
# x71 = 0.7034674224983917
#
#
# iteração = 71
# f(x71) = 0.0
# A solução foi encontrada após 70 iterações.
# f`(x71) = 1.901801259513314
# x72 = 0.7034674224983917 - (0.0/1.901801259513314)
# x72 = 0.7034674224983917
#
#
# iteração = 72
# f(x72) = 0.0
# A solução foi encontrada após 71 iterações.
# f`(x72) = 1.901801259513314
# x73 = 0.7034674224983917 - (0.0/1.901801259513314)
# x73 = 0.7034674224983917
#
#
# iteração = 73
# f(x73) = 0.0
# A solução foi encontrada após 72 iterações.
# f`(x73) = 1.901801259513314
# x74 = 0.7034674224983917 - (0.0/1.901801259513314)
# x74 = 0.7034674224983917
#
#
# iteração = 74
# f(x74) = 0.0
# A solução foi encontrada após 73 iterações.
# f`(x74) = 1.901801259513314
# x75 = 0.7034674224983917 - (0.0/1.901801259513314)
# x75 = 0.7034674224983917
#
#
# iteração = 75
# f(x75) = 0.0
# A solução foi encontrada após 74 iterações.
# f`(x75) = 1.901801259513314
# x76 = 0.7034674224983917 - (0.0/1.901801259513314)
# x76 = 0.7034674224983917
#
#
# iteração = 76
# f(x76) = 0.0
# A solução foi encontrada após 75 iterações.
# f`(x76) = 1.901801259513314
# x77 = 0.7034674224983917 - (0.0/1.901801259513314)
# x77 = 0.7034674224983917
#
#
# iteração = 77
# f(x77) = 0.0
# A solução foi encontrada após 76 iterações.
# f`(x77) = 1.901801259513314
# x78 = 0.7034674224983917 - (0.0/1.901801259513314)
# x78 = 0.7034674224983917
#
#
# iteração = 78
# f(x78) = 0.0
# A solução foi encontrada após 77 iterações.
# f`(x78) = 1.901801259513314
# x79 = 0.7034674224983917 - (0.0/1.901801259513314)
# x79 = 0.7034674224983917
#
#
# iteração = 79
# f(x79) = 0.0
# A solução foi encontrada após 78 iterações.
# f`(x79) = 1.901801259513314
# x80 = 0.7034674224983917 - (0.0/1.901801259513314)
# x80 = 0.7034674224983917
#
#
# iteração = 80
# f(x80) = 0.0
# A solução foi encontrada após 79 iterações.
# f`(x80) = 1.901801259513314
# x81 = 0.7034674224983917 - (0.0/1.901801259513314)
# x81 = 0.7034674224983917
#
#
# iteração = 81
# f(x81) = 0.0
# A solução foi encontrada após 80 iterações.
# f`(x81) = 1.901801259513314
# x82 = 0.7034674224983917 - (0.0/1.901801259513314)
# x82 = 0.7034674224983917
#
#
# iteração = 82
# f(x82) = 0.0
# A solução foi encontrada após 81 iterações.
# f`(x82) = 1.901801259513314
# x83 = 0.7034674224983917 - (0.0/1.901801259513314)
# x83 = 0.7034674224983917
#
#
# iteração = 83
# f(x83) = 0.0
# A solução foi encontrada após 82 iterações.
# f`(x83) = 1.901801259513314
# x84 = 0.7034674224983917 - (0.0/1.901801259513314)
# x84 = 0.7034674224983917
#
#
# iteração = 84
# f(x84) = 0.0
# A solução foi encontrada após 83 iterações.
# f`(x84) = 1.901801259513314
# x85 = 0.7034674224983917 - (0.0/1.901801259513314)
# x85 = 0.7034674224983917
#
#
# iteração = 85
# f(x85) = 0.0
# A solução foi encontrada após 84 iterações.
# f`(x85) = 1.901801259513314
# x86 = 0.7034674224983917 - (0.0/1.901801259513314)
# x86 = 0.7034674224983917
#
#
# iteração = 86
# f(x86) = 0.0
# A solução foi encontrada após 85 iterações.
# f`(x86) = 1.901801259513314
# x87 = 0.7034674224983917 - (0.0/1.901801259513314)
# x87 = 0.7034674224983917
#
#
# iteração = 87
# f(x87) = 0.0
# A solução foi encontrada após 86 iterações.
# f`(x87) = 1.901801259513314
# x88 = 0.7034674224983917 - (0.0/1.901801259513314)
# x88 = 0.7034674224983917
#
#
# iteração = 88
# f(x88) = 0.0
# A solução foi encontrada após 87 iterações.
# f`(x88) = 1.901801259513314
# x89 = 0.7034674224983917 - (0.0/1.901801259513314)
# x89 = 0.7034674224983917
#
#
# iteração = 89
# f(x89) = 0.0
# A solução foi encontrada após 88 iterações.
# f`(x89) = 1.901801259513314
# x90 = 0.7034674224983917 - (0.0/1.901801259513314)
# x90 = 0.7034674224983917
#
#
# iteração = 90
# f(x90) = 0.0
# A solução foi encontrada após 89 iterações.
# f`(x90) = 1.901801259513314
# x91 = 0.7034674224983917 - (0.0/1.901801259513314)
# x91 = 0.7034674224983917
#
#
# iteração = 91
# f(x91) = 0.0
# A solução foi encontrada após 90 iterações.
# f`(x91) = 1.901801259513314
# x92 = 0.7034674224983917 - (0.0/1.901801259513314)
# x92 = 0.7034674224983917
#
#
# iteração = 92
# f(x92) = 0.0
# A solução foi encontrada após 91 iterações.
# f`(x92) = 1.901801259513314
# x93 = 0.7034674224983917 - (0.0/1.901801259513314)
# x93 = 0.7034674224983917
#
#
# iteração = 93
# f(x93) = 0.0
# A solução foi encontrada após 92 iterações.
# f`(x93) = 1.901801259513314
# x94 = 0.7034674224983917 - (0.0/1.901801259513314)
# x94 = 0.7034674224983917
#
#
# iteração = 94
# f(x94) = 0.0
# A solução foi encontrada após 93 iterações.
# f`(x94) = 1.901801259513314
# x95 = 0.7034674224983917 - (0.0/1.901801259513314)
# x95 = 0.7034674224983917
#
#
# iteração = 95
# f(x95) = 0.0
# A solução foi encontrada após 94 iterações.
# f`(x95) = 1.901801259513314
# x96 = 0.7034674224983917 - (0.0/1.901801259513314)
# x96 = 0.7034674224983917
#
#
# iteração = 96
# f(x96) = 0.0
# A solução foi encontrada após 95 iterações.
# f`(x96) = 1.901801259513314
# x97 = 0.7034674224983917 - (0.0/1.901801259513314)
# x97 = 0.7034674224983917
#
#
# iteração = 97
# f(x97) = 0.0
# A solução foi encontrada após 96 iterações.
# f`(x97) = 1.901801259513314
# x98 = 0.7034674224983917 - (0.0/1.901801259513314)
# x98 = 0.7034674224983917
#
#
# iteração = 98
# f(x98) = 0.0
# A solução foi encontrada após 97 iterações.
# f`(x98) = 1.901801259513314
# x99 = 0.7034674224983917 - (0.0/1.901801259513314)
# x99 = 0.7034674224983917
#
#
# iteração = 99
# f(x99) = 0.0
# A solução foi encontrada após 98 iterações.
# f`(x99) = 1.901801259513314
# x100 = 0.7034674224983917 - (0.0/1.901801259513314)
# x100 = 0.7034674224983917
#
#
# iteração = 100
# f(x100) = 0.0
# A solução foi encontrada após 99 iterações.
# f`(x100) = 1.901801259513314
# x101 = 0.7034674224983917 - (0.0/1.901801259513314)
# x101 = 0.7034674224983917
#
#
# iteração = 101
# f(x101) = 0.0
# A solução foi encontrada após 100 iterações.
# f`(x101) = 1.901801259513314
# x102 = 0.7034674224983917 - (0.0/1.901801259513314)
# x102 = 0.7034674224983917
#
#
# iteração = 102
# f(x102) = 0.0
# A solução foi encontrada após 101 iterações.
# f`(x102) = 1.901801259513314
# x103 = 0.7034674224983917 - (0.0/1.901801259513314)
# x103 = 0.7034674224983917
#
#
# iteração = 103
# f(x103) = 0.0
# A solução foi encontrada após 102 iterações.
# f`(x103) = 1.901801259513314
# x104 = 0.7034674224983917 - (0.0/1.901801259513314)
# x104 = 0.7034674224983917
#
#
# iteração = 104
# f(x104) = 0.0
# A solução foi encontrada após 103 iterações.
# f`(x104) = 1.901801259513314
# x105 = 0.7034674224983917 - (0.0/1.901801259513314)
# x105 = 0.7034674224983917
#
#
# iteração = 105
# f(x105) = 0.0
# A solução foi encontrada após 104 iterações.
# f`(x105) = 1.901801259513314
# x106 = 0.7034674224983917 - (0.0/1.901801259513314)
# x106 = 0.7034674224983917
#
#
# iteração = 106
# f(x106) = 0.0
# A solução foi encontrada após 105 iterações.
# f`(x106) = 1.901801259513314
# x107 = 0.7034674224983917 - (0.0/1.901801259513314)
# x107 = 0.7034674224983917
#
#
# iteração = 107
# f(x107) = 0.0
# A solução foi encontrada após 106 iterações.
# f`(x107) = 1.901801259513314
# x108 = 0.7034674224983917 - (0.0/1.901801259513314)
# x108 = 0.7034674224983917
#
#
# iteração = 108
# f(x108) = 0.0
# A solução foi encontrada após 107 iterações.
# f`(x108) = 1.901801259513314
# x109 = 0.7034674224983917 - (0.0/1.901801259513314)
# x109 = 0.7034674224983917
#
#
# iteração = 109
# f(x109) = 0.0
# A solução foi encontrada após 108 iterações.
# f`(x109) = 1.901801259513314
# x110 = 0.7034674224983917 - (0.0/1.901801259513314)
# x110 = 0.7034674224983917
#
#
# iteração = 110
# f(x110) = 0.0
# A solução foi encontrada após 109 iterações.
# f`(x110) = 1.901801259513314
# x111 = 0.7034674224983917 - (0.0/1.901801259513314)
# x111 = 0.7034674224983917
#
#
# iteração = 111
# f(x111) = 0.0
# A solução foi encontrada após 110 iterações.
# f`(x111) = 1.901801259513314
# x112 = 0.7034674224983917 - (0.0/1.901801259513314)
# x112 = 0.7034674224983917
#
#
# iteração = 112
# f(x112) = 0.0
# A solução foi encontrada após 111 iterações.
# f`(x112) = 1.901801259513314
# x113 = 0.7034674224983917 - (0.0/1.901801259513314)
# x113 = 0.7034674224983917
#
#
# iteração = 113
# f(x113) = 0.0
# A solução foi encontrada após 112 iterações.
# f`(x113) = 1.901801259513314
# x114 = 0.7034674224983917 - (0.0/1.901801259513314)
# x114 = 0.7034674224983917
#
#
# iteração = 114
# f(x114) = 0.0
# A solução foi encontrada após 113 iterações.
# f`(x114) = 1.901801259513314
# x115 = 0.7034674224983917 - (0.0/1.901801259513314)
# x115 = 0.7034674224983917
#
#
# iteração = 115
# f(x115) = 0.0
# A solução foi encontrada após 114 iterações.
# f`(x115) = 1.901801259513314
# x116 = 0.7034674224983917 - (0.0/1.901801259513314)
# x116 = 0.7034674224983917
#
#
# iteração = 116
# f(x116) = 0.0
# A solução foi encontrada após 115 iterações.
# f`(x116) = 1.901801259513314
# x117 = 0.7034674224983917 - (0.0/1.901801259513314)
# x117 = 0.7034674224983917
#
#
# iteração = 117
# f(x117) = 0.0
# A solução foi encontrada após 116 iterações.
# f`(x117) = 1.901801259513314
# x118 = 0.7034674224983917 - (0.0/1.901801259513314)
# x118 = 0.7034674224983917
#
#
# iteração = 118
# f(x118) = 0.0
# A solução foi encontrada após 117 iterações.
# f`(x118) = 1.901801259513314
# x119 = 0.7034674224983917 - (0.0/1.901801259513314)
# x119 = 0.7034674224983917
#
#
# iteração = 119
# f(x119) = 0.0
# A solução foi encontrada após 118 iterações.
# f`(x119) = 1.901801259513314
# x120 = 0.7034674224983917 - (0.0/1.901801259513314)
# x120 = 0.7034674224983917
#
#
# iteração = 120
# f(x120) = 0.0
# A solução foi encontrada após 119 iterações.
# f`(x120) = 1.901801259513314
# x121 = 0.7034674224983917 - (0.0/1.901801259513314)
# x121 = 0.7034674224983917
#
#
# iteração = 121
# f(x121) = 0.0
# A solução foi encontrada após 120 iterações.
# f`(x121) = 1.901801259513314
# x122 = 0.7034674224983917 - (0.0/1.901801259513314)
# x122 = 0.7034674224983917
#
#
# iteração = 122
# f(x122) = 0.0
# A solução foi encontrada após 121 iterações.
# f`(x122) = 1.901801259513314
# x123 = 0.7034674224983917 - (0.0/1.901801259513314)
# x123 = 0.7034674224983917
#
#
# iteração = 123
# f(x123) = 0.0
# A solução foi encontrada após 122 iterações.
# f`(x123) = 1.901801259513314
# x124 = 0.7034674224983917 - (0.0/1.901801259513314)
# x124 = 0.7034674224983917
#
#
# iteração = 124
# f(x124) = 0.0
# A solução foi encontrada após 123 iterações.
# f`(x124) = 1.901801259513314
# x125 = 0.7034674224983917 - (0.0/1.901801259513314)
# x125 = 0.7034674224983917
#
#
# iteração = 125
# f(x125) = 0.0
# A solução foi encontrada após 124 iterações.
# f`(x125) = 1.901801259513314
# x126 = 0.7034674224983917 - (0.0/1.901801259513314)
# x126 = 0.7034674224983917
#
#
# iteração = 126
# f(x126) = 0.0
# A solução foi encontrada após 125 iterações.
# f`(x126) = 1.901801259513314
# x127 = 0.7034674224983917 - (0.0/1.901801259513314)
# x127 = 0.7034674224983917
#
#
# iteração = 127
# f(x127) = 0.0
# A solução foi encontrada após 126 iterações.
# f`(x127) = 1.901801259513314
# x128 = 0.7034674224983917 - (0.0/1.901801259513314)
# x128 = 0.7034674224983917
#
#
# iteração = 128
# f(x128) = 0.0
# A solução foi encontrada após 127 iterações.
# f`(x128) = 1.901801259513314
# x129 = 0.7034674224983917 - (0.0/1.901801259513314)
# x129 = 0.7034674224983917
#
#
# iteração = 129
# f(x129) = 0.0
# A solução foi encontrada após 128 iterações.
# f`(x129) = 1.901801259513314
# x130 = 0.7034674224983917 - (0.0/1.901801259513314)
# x130 = 0.7034674224983917
#
#
# iteração = 130
# f(x130) = 0.0
# A solução foi encontrada após 129 iterações.
# f`(x130) = 1.901801259513314
# x131 = 0.7034674224983917 - (0.0/1.901801259513314)
# x131 = 0.7034674224983917
#
#
# iteração = 131
# f(x131) = 0.0
# A solução foi encontrada após 130 iterações.
# f`(x131) = 1.901801259513314
# x132 = 0.7034674224983917 - (0.0/1.901801259513314)
# x132 = 0.7034674224983917
#
#
# iteração = 132
# f(x132) = 0.0
# A solução foi encontrada após 131 iterações.
# f`(x132) = 1.901801259513314
# x133 = 0.7034674224983917 - (0.0/1.901801259513314)
# x133 = 0.7034674224983917
#
#
# iteração = 133
# f(x133) = 0.0
# A solução foi encontrada após 132 iterações.
# f`(x133) = 1.901801259513314
# x134 = 0.7034674224983917 - (0.0/1.901801259513314)
# x134 = 0.7034674224983917
#
#
# iteração = 134
# f(x134) = 0.0
# A solução foi encontrada após 133 iterações.
# f`(x134) = 1.901801259513314
# x135 = 0.7034674224983917 - (0.0/1.901801259513314)
# x135 = 0.7034674224983917
#
#
# iteração = 135
# f(x135) = 0.0
# A solução foi encontrada após 134 iterações.
# f`(x135) = 1.901801259513314
# x136 = 0.7034674224983917 - (0.0/1.901801259513314)
# x136 = 0.7034674224983917
#
#
# iteração = 136
# f(x136) = 0.0
# A solução foi encontrada após 135 iterações.
# f`(x136) = 1.901801259513314
# x137 = 0.7034674224983917 - (0.0/1.901801259513314)
# x137 = 0.7034674224983917
#
#
# iteração = 137
# f(x137) = 0.0
# A solução foi encontrada após 136 iterações.
# f`(x137) = 1.901801259513314
# x138 = 0.7034674224983917 - (0.0/1.901801259513314)
# x138 = 0.7034674224983917
#
#
# iteração = 138
# f(x138) = 0.0
# A solução foi encontrada após 137 iterações.
# f`(x138) = 1.901801259513314
# x139 = 0.7034674224983917 - (0.0/1.901801259513314)
# x139 = 0.7034674224983917
#
#
# iteração = 139
# f(x139) = 0.0
# A solução foi encontrada após 138 iterações.
# f`(x139) = 1.901801259513314
# x140 = 0.7034674224983917 - (0.0/1.901801259513314)
# x140 = 0.7034674224983917
#
#
# iteração = 140
# f(x140) = 0.0
# A solução foi encontrada após 139 iterações.
# f`(x140) = 1.901801259513314
# x141 = 0.7034674224983917 - (0.0/1.901801259513314)
# x141 = 0.7034674224983917
#
#
# iteração = 141
# f(x141) = 0.0
# A solução foi encontrada após 140 iterações.
# f`(x141) = 1.901801259513314
# x142 = 0.7034674224983917 - (0.0/1.901801259513314)
# x142 = 0.7034674224983917
#
#
# iteração = 142
# f(x142) = 0.0
# A solução foi encontrada após 141 iterações.
# f`(x142) = 1.901801259513314
# x143 = 0.7034674224983917 - (0.0/1.901801259513314)
# x143 = 0.7034674224983917
#
#
# iteração = 143
# f(x143) = 0.0
# A solução foi encontrada após 142 iterações.
# f`(x143) = 1.901801259513314
# x144 = 0.7034674224983917 - (0.0/1.901801259513314)
# x144 = 0.7034674224983917
#
#
# iteração = 144
# f(x144) = 0.0
# A solução foi encontrada após 143 iterações.
# f`(x144) = 1.901801259513314
# x145 = 0.7034674224983917 - (0.0/1.901801259513314)
# x145 = 0.7034674224983917
#
#
# iteração = 145
# f(x145) = 0.0
# A solução foi encontrada após 144 iterações.
# f`(x145) = 1.901801259513314
# x146 = 0.7034674224983917 - (0.0/1.901801259513314)
# x146 = 0.7034674224983917
#
#
# iteração = 146
# f(x146) = 0.0
# A solução foi encontrada após 145 iterações.
# f`(x146) = 1.901801259513314
# x147 = 0.7034674224983917 - (0.0/1.901801259513314)
# x147 = 0.7034674224983917
#
#
# iteração = 147
# f(x147) = 0.0
# A solução foi encontrada após 146 iterações.
# f`(x147) = 1.901801259513314
# x148 = 0.7034674224983917 - (0.0/1.901801259513314)
# x148 = 0.7034674224983917
#
#
# iteração = 148
# f(x148) = 0.0
# A solução foi encontrada após 147 iterações.
# f`(x148) = 1.901801259513314
# x149 = 0.7034674224983917 - (0.0/1.901801259513314)
# x149 = 0.7034674224983917
#
#
# iteração = 149
# f(x149) = 0.0
# A solução foi encontrada após 148 iterações.
# f`(x149) = 1.901801259513314
# x150 = 0.7034674224983917 - (0.0/1.901801259513314)
# x150 = 0.7034674224983917
#
#
# iteração = 150
# f(x150) = 0.0
# A solução foi encontrada após 149 iterações.
# f`(x150) = 1.901801259513314
# x151 = 0.7034674224983917 - (0.0/1.901801259513314)
# x151 = 0.7034674224983917
#
#
# iteração = 151
# f(x151) = 0.0
# A solução foi encontrada após 150 iterações.
# f`(x151) = 1.901801259513314
# x152 = 0.7034674224983917 - (0.0/1.901801259513314)
# x152 = 0.7034674224983917
#
#
# iteração = 152
# f(x152) = 0.0
# A solução foi encontrada após 151 iterações.
# f`(x152) = 1.901801259513314
# x153 = 0.7034674224983917 - (0.0/1.901801259513314)
# x153 = 0.7034674224983917
#
#
# iteração = 153
# f(x153) = 0.0
# A solução foi encontrada após 152 iterações.
# f`(x153) = 1.901801259513314
# x154 = 0.7034674224983917 - (0.0/1.901801259513314)
# x154 = 0.7034674224983917
#
#
# iteração = 154
# f(x154) = 0.0
# A solução foi encontrada após 153 iterações.
# f`(x154) = 1.901801259513314
# x155 = 0.7034674224983917 - (0.0/1.901801259513314)
# x155 = 0.7034674224983917
#
#
# iteração = 155
# f(x155) = 0.0
# A solução foi encontrada após 154 iterações.
# f`(x155) = 1.901801259513314
# x156 = 0.7034674224983917 - (0.0/1.901801259513314)
# x156 = 0.7034674224983917
#
#
# iteração = 156
# f(x156) = 0.0
# A solução foi encontrada após 155 iterações.
# f`(x156) = 1.901801259513314
# x157 = 0.7034674224983917 - (0.0/1.901801259513314)
# x157 = 0.7034674224983917
#
#
# iteração = 157
# f(x157) = 0.0
# A solução foi encontrada após 156 iterações.
# f`(x157) = 1.901801259513314
# x158 = 0.7034674224983917 - (0.0/1.901801259513314)
# x158 = 0.7034674224983917
#
#
# iteração = 158
# f(x158) = 0.0
# A solução foi encontrada após 157 iterações.
# f`(x158) = 1.901801259513314
# x159 = 0.7034674224983917 - (0.0/1.901801259513314)
# x159 = 0.7034674224983917
#
#
# iteração = 159
# f(x159) = 0.0
# A solução foi encontrada após 158 iterações.
# f`(x159) = 1.901801259513314
# x160 = 0.7034674224983917 - (0.0/1.901801259513314)
# x160 = 0.7034674224983917
#
#
# iteração = 160
# f(x160) = 0.0
# A solução foi encontrada após 159 iterações.
# f`(x160) = 1.901801259513314
# x161 = 0.7034674224983917 - (0.0/1.901801259513314)
# x161 = 0.7034674224983917
#
#
# iteração = 161
# f(x161) = 0.0
# A solução foi encontrada após 160 iterações.
# f`(x161) = 1.901801259513314
# x162 = 0.7034674224983917 - (0.0/1.901801259513314)
# x162 = 0.7034674224983917
#
#
# iteração = 162
# f(x162) = 0.0
# A solução foi encontrada após 161 iterações.
# f`(x162) = 1.901801259513314
# x163 = 0.7034674224983917 - (0.0/1.901801259513314)
# x163 = 0.7034674224983917
#
#
# iteração = 163
# f(x163) = 0.0
# A solução foi encontrada após 162 iterações.
# f`(x163) = 1.901801259513314
# x164 = 0.7034674224983917 - (0.0/1.901801259513314)
# x164 = 0.7034674224983917
#
#
# iteração = 164
# f(x164) = 0.0
# A solução foi encontrada após 163 iterações.
# f`(x164) = 1.901801259513314
# x165 = 0.7034674224983917 - (0.0/1.901801259513314)
# x165 = 0.7034674224983917
#
#
# iteração = 165
# f(x165) = 0.0
# A solução foi encontrada após 164 iterações.
# f`(x165) = 1.901801259513314
# x166 = 0.7034674224983917 - (0.0/1.901801259513314)
# x166 = 0.7034674224983917
#
#
# iteração = 166
# f(x166) = 0.0
# A solução foi encontrada após 165 iterações.
# f`(x166) = 1.901801259513314
# x167 = 0.7034674224983917 - (0.0/1.901801259513314)
# x167 = 0.7034674224983917
#
#
# iteração = 167
# f(x167) = 0.0
# A solução foi encontrada após 166 iterações.
# f`(x167) = 1.901801259513314
# x168 = 0.7034674224983917 - (0.0/1.901801259513314)
# x168 = 0.7034674224983917
#
#
# iteração = 168
# f(x168) = 0.0
# A solução foi encontrada após 167 iterações.
# f`(x168) = 1.901801259513314
# x169 = 0.7034674224983917 - (0.0/1.901801259513314)
# x169 = 0.7034674224983917
#
#
# iteração = 169
# f(x169) = 0.0
# A solução foi encontrada após 168 iterações.
# f`(x169) = 1.901801259513314
# x170 = 0.7034674224983917 - (0.0/1.901801259513314)
# x170 = 0.7034674224983917
#
#
# iteração = 170
# f(x170) = 0.0
# A solução foi encontrada após 169 iterações.
# f`(x170) = 1.901801259513314
# x171 = 0.7034674224983917 - (0.0/1.901801259513314)
# x171 = 0.7034674224983917
#
#
# iteração = 171
# f(x171) = 0.0
# A solução foi encontrada após 170 iterações.
# f`(x171) = 1.901801259513314
# x172 = 0.7034674224983917 - (0.0/1.901801259513314)
# x172 = 0.7034674224983917
#
#
# iteração = 172
# f(x172) = 0.0
# A solução foi encontrada após 171 iterações.
# f`(x172) = 1.901801259513314
# x173 = 0.7034674224983917 - (0.0/1.901801259513314)
# x173 = 0.7034674224983917
#
#
# iteração = 173
# f(x173) = 0.0
# A solução foi encontrada após 172 iterações.
# f`(x173) = 1.901801259513314
# x174 = 0.7034674224983917 - (0.0/1.901801259513314)
# x174 = 0.7034674224983917
#
#
# iteração = 174
# f(x174) = 0.0
# A solução foi encontrada após 173 iterações.
# f`(x174) = 1.901801259513314
# x175 = 0.7034674224983917 - (0.0/1.901801259513314)
# x175 = 0.7034674224983917
#
#
# iteração = 175
# f(x175) = 0.0
# A solução foi encontrada após 174 iterações.
# f`(x175) = 1.901801259513314
# x176 = 0.7034674224983917 - (0.0/1.901801259513314)
# x176 = 0.7034674224983917
#
#
# iteração = 176
# f(x176) = 0.0
# A solução foi encontrada após 175 iterações.
# f`(x176) = 1.901801259513314
# x177 = 0.7034674224983917 - (0.0/1.901801259513314)
# x177 = 0.7034674224983917
#
#
# iteração = 177
# f(x177) = 0.0
# A solução foi encontrada após 176 iterações.
# f`(x177) = 1.901801259513314
# x178 = 0.7034674224983917 - (0.0/1.901801259513314)
# x178 = 0.7034674224983917
#
#
# iteração = 178
# f(x178) = 0.0
# A solução foi encontrada após 177 iterações.
# f`(x178) = 1.901801259513314
# x179 = 0.7034674224983917 - (0.0/1.901801259513314)
# x179 = 0.7034674224983917
#
#
# iteração = 179
# f(x179) = 0.0
# A solução foi encontrada após 178 iterações.
# f`(x179) = 1.901801259513314
# x180 = 0.7034674224983917 - (0.0/1.901801259513314)
# x180 = 0.7034674224983917
#
#
# iteração = 180
# f(x180) = 0.0
# A solução foi encontrada após 179 iterações.
# f`(x180) = 1.901801259513314
# x181 = 0.7034674224983917 - (0.0/1.901801259513314)
# x181 = 0.7034674224983917
#
#
# iteração = 181
# f(x181) = 0.0
# A solução foi encontrada após 180 iterações.
# f`(x181) = 1.901801259513314
# x182 = 0.7034674224983917 - (0.0/1.901801259513314)
# x182 = 0.7034674224983917
#
#
# iteração = 182
# f(x182) = 0.0
# A solução foi encontrada após 181 iterações.
# f`(x182) = 1.901801259513314
# x183 = 0.7034674224983917 - (0.0/1.901801259513314)
# x183 = 0.7034674224983917
#
#
# iteração = 183
# f(x183) = 0.0
# A solução foi encontrada após 182 iterações.
# f`(x183) = 1.901801259513314
# x184 = 0.7034674224983917 - (0.0/1.901801259513314)
# x184 = 0.7034674224983917
#
#
# iteração = 184
# f(x184) = 0.0
# A solução foi encontrada após 183 iterações.
# f`(x184) = 1.901801259513314
# x185 = 0.7034674224983917 - (0.0/1.901801259513314)
# x185 = 0.7034674224983917
#
#
# iteração = 185
# f(x185) = 0.0
# A solução foi encontrada após 184 iterações.
# f`(x185) = 1.901801259513314
# x186 = 0.7034674224983917 - (0.0/1.901801259513314)
# x186 = 0.7034674224983917
#
#
# iteração = 186
# f(x186) = 0.0
# A solução foi encontrada após 185 iterações.
# f`(x186) = 1.901801259513314
# x187 = 0.7034674224983917 - (0.0/1.901801259513314)
# x187 = 0.7034674224983917
#
#
# iteração = 187
# f(x187) = 0.0
# A solução foi encontrada após 186 iterações.
# f`(x187) = 1.901801259513314
# x188 = 0.7034674224983917 - (0.0/1.901801259513314)
# x188 = 0.7034674224983917
#
#
# iteração = 188
# f(x188) = 0.0
# A solução foi encontrada após 187 iterações.
# f`(x188) = 1.901801259513314
# x189 = 0.7034674224983917 - (0.0/1.901801259513314)
# x189 = 0.7034674224983917
#
#
# iteração = 189
# f(x189) = 0.0
# A solução foi encontrada após 188 iterações.
# f`(x189) = 1.901801259513314
# x190 = 0.7034674224983917 - (0.0/1.901801259513314)
# x190 = 0.7034674224983917
#
#
# iteração = 190
# f(x190) = 0.0
# A solução foi encontrada após 189 iterações.
# f`(x190) = 1.901801259513314
# x191 = 0.7034674224983917 - (0.0/1.901801259513314)
# x191 = 0.7034674224983917
#
#
# iteração = 191
# f(x191) = 0.0
# A solução foi encontrada após 190 iterações.
# f`(x191) = 1.901801259513314
# x192 = 0.7034674224983917 - (0.0/1.901801259513314)
# x192 = 0.7034674224983917
#
#
# iteração = 192
# f(x192) = 0.0
# A solução foi encontrada após 191 iterações.
# f`(x192) = 1.901801259513314
# x193 = 0.7034674224983917 - (0.0/1.901801259513314)
# x193 = 0.7034674224983917
#
#
# iteração = 193
# f(x193) = 0.0
# A solução foi encontrada após 192 iterações.
# f`(x193) = 1.901801259513314
# x194 = 0.7034674224983917 - (0.0/1.901801259513314)
# x194 = 0.7034674224983917
#
#
# iteração = 194
# f(x194) = 0.0
# A solução foi encontrada após 193 iterações.
# f`(x194) = 1.901801259513314
# x195 = 0.7034674224983917 - (0.0/1.901801259513314)
# x195 = 0.7034674224983917
#
#
# iteração = 195
# f(x195) = 0.0
# A solução foi encontrada após 194 iterações.
# f`(x195) = 1.901801259513314
# x196 = 0.7034674224983917 - (0.0/1.901801259513314)
# x196 = 0.7034674224983917
#
#
# iteração = 196
# f(x196) = 0.0
# A solução foi encontrada após 195 iterações.
# f`(x196) = 1.901801259513314
# x197 = 0.7034674224983917 - (0.0/1.901801259513314)
# x197 = 0.7034674224983917
#
#
# iteração = 197
# f(x197) = 0.0
# A solução foi encontrada após 196 iterações.
# f`(x197) = 1.901801259513314
# x198 = 0.7034674224983917 - (0.0/1.901801259513314)
# x198 = 0.7034674224983917
#
#
# iteração = 198
# f(x198) = 0.0
# A solução foi encontrada após 197 iterações.
# f`(x198) = 1.901801259513314
# x199 = 0.7034674224983917 - (0.0/1.901801259513314)
# x199 = 0.7034674224983917
#
#
# iteração = 199
# f(x199) = 0.0
# A solução foi encontrada após 198 iterações.
# f`(x199) = 1.901801259513314
# x200 = 0.7034674224983917 - (0.0/1.901801259513314)
# x200 = 0.7034674224983917
#
#
# iteração = 200
# f(x200) = 0.0
# A solução foi encontrada após 199 iterações.
# f`(x200) = 1.901801259513314
# x201 = 0.7034674224983917 - (0.0/1.901801259513314)
# x201 = 0.7034674224983917
#
#
# iteração = 201
# f(x201) = 0.0
# A solução foi encontrada após 200 iterações.
# f`(x201) = 1.901801259513314
# x202 = 0.7034674224983917 - (0.0/1.901801259513314)
# x202 = 0.7034674224983917
#
#
# iteração = 202
# f(x202) = 0.0
# A solução foi encontrada após 201 iterações.
# f`(x202) = 1.901801259513314
# x203 = 0.7034674224983917 - (0.0/1.901801259513314)
# x203 = 0.7034674224983917
#
#
# iteração = 203
# f(x203) = 0.0
# A solução foi encontrada após 202 iterações.
# f`(x203) = 1.901801259513314
# x204 = 0.7034674224983917 - (0.0/1.901801259513314)
# x204 = 0.7034674224983917
#
#
# iteração = 204
# f(x204) = 0.0
# A solução foi encontrada após 203 iterações.
# f`(x204) = 1.901801259513314
# x205 = 0.7034674224983917 - (0.0/1.901801259513314)
# x205 = 0.7034674224983917
#
#
# iteração = 205
# f(x205) = 0.0
# A solução foi encontrada após 204 iterações.
# f`(x205) = 1.901801259513314
# x206 = 0.7034674224983917 - (0.0/1.901801259513314)
# x206 = 0.7034674224983917
#
#
# iteração = 206
# f(x206) = 0.0
# A solução foi encontrada após 205 iterações.
# f`(x206) = 1.901801259513314
# x207 = 0.7034674224983917 - (0.0/1.901801259513314)
# x207 = 0.7034674224983917
#
#
# iteração = 207
# f(x207) = 0.0
# A solução foi encontrada após 206 iterações.
# f`(x207) = 1.901801259513314
# x208 = 0.7034674224983917 - (0.0/1.901801259513314)
# x208 = 0.7034674224983917
#
#
# iteração = 208
# f(x208) = 0.0
# A solução foi encontrada após 207 iterações.
# f`(x208) = 1.901801259513314
# x209 = 0.7034674224983917 - (0.0/1.901801259513314)
# x209 = 0.7034674224983917
#
#
# iteração = 209
# f(x209) = 0.0
# A solução foi encontrada após 208 iterações.
# f`(x209) = 1.901801259513314
# x210 = 0.7034674224983917 - (0.0/1.901801259513314)
# x210 = 0.7034674224983917
#
#
# iteração = 210
# f(x210) = 0.0
# A solução foi encontrada após 209 iterações.
# f`(x210) = 1.901801259513314
# x211 = 0.7034674224983917 - (0.0/1.901801259513314)
# x211 = 0.7034674224983917
#
#
# iteração = 211
# f(x211) = 0.0
# A solução foi encontrada após 210 iterações.
# f`(x211) = 1.901801259513314
# x212 = 0.7034674224983917 - (0.0/1.901801259513314)
# x212 = 0.7034674224983917
#
#
# iteração = 212
# f(x212) = 0.0
# A solução foi encontrada após 211 iterações.
# f`(x212) = 1.901801259513314
# x213 = 0.7034674224983917 - (0.0/1.901801259513314)
# x213 = 0.7034674224983917
#
#
# iteração = 213
# f(x213) = 0.0
# A solução foi encontrada após 212 iterações.
# f`(x213) = 1.901801259513314
# x214 = 0.7034674224983917 - (0.0/1.901801259513314)
# x214 = 0.7034674224983917
#
#
# iteração = 214
# f(x214) = 0.0
# A solução foi encontrada após 213 iterações.
# f`(x214) = 1.901801259513314
# x215 = 0.7034674224983917 - (0.0/1.901801259513314)
# x215 = 0.7034674224983917
#
#
# iteração = 215
# f(x215) = 0.0
# A solução foi encontrada após 214 iterações.
# f`(x215) = 1.901801259513314
# x216 = 0.7034674224983917 - (0.0/1.901801259513314)
# x216 = 0.7034674224983917
#
#
# iteração = 216
# f(x216) = 0.0
# A solução foi encontrada após 215 iterações.
# f`(x216) = 1.901801259513314
# x217 = 0.7034674224983917 - (0.0/1.901801259513314)
# x217 = 0.7034674224983917
#
#
# iteração = 217
# f(x217) = 0.0
# A solução foi encontrada após 216 iterações.
# f`(x217) = 1.901801259513314
# x218 = 0.7034674224983917 - (0.0/1.901801259513314)
# x218 = 0.7034674224983917
#
#
# iteração = 218
# f(x218) = 0.0
# A solução foi encontrada após 217 iterações.
# f`(x218) = 1.901801259513314
# x219 = 0.7034674224983917 - (0.0/1.901801259513314)
# x219 = 0.7034674224983917
#
#
# iteração = 219
# f(x219) = 0.0
# A solução foi encontrada após 218 iterações.
# f`(x219) = 1.901801259513314
# x220 = 0.7034674224983917 - (0.0/1.901801259513314)
# x220 = 0.7034674224983917
#
#
# iteração = 220
# f(x220) = 0.0
# A solução foi encontrada após 219 iterações.
# f`(x220) = 1.901801259513314
# x221 = 0.7034674224983917 - (0.0/1.901801259513314)
# x221 = 0.7034674224983917
#
#
# iteração = 221
# f(x221) = 0.0
# A solução foi encontrada após 220 iterações.
# f`(x221) = 1.901801259513314
# x222 = 0.7034674224983917 - (0.0/1.901801259513314)
# x222 = 0.7034674224983917
#
#
# iteração = 222
# f(x222) = 0.0
# A solução foi encontrada após 221 iterações.
# f`(x222) = 1.901801259513314
# x223 = 0.7034674224983917 - (0.0/1.901801259513314)
# x223 = 0.7034674224983917
#
#
# iteração = 223
# f(x223) = 0.0
# A solução foi encontrada após 222 iterações.
# f`(x223) = 1.901801259513314
# x224 = 0.7034674224983917 - (0.0/1.901801259513314)
# x224 = 0.7034674224983917
#
#
# iteração = 224
# f(x224) = 0.0
# A solução foi encontrada após 223 iterações.
# f`(x224) = 1.901801259513314
# x225 = 0.7034674224983917 - (0.0/1.901801259513314)
# x225 = 0.7034674224983917
#
#
# iteração = 225
# f(x225) = 0.0
# A solução foi encontrada após 224 iterações.
# f`(x225) = 1.901801259513314
# x226 = 0.7034674224983917 - (0.0/1.901801259513314)
# x226 = 0.7034674224983917
#
#
# iteração = 226
# f(x226) = 0.0
# A solução foi encontrada após 225 iterações.
# f`(x226) = 1.901801259513314
# x227 = 0.7034674224983917 - (0.0/1.901801259513314)
# x227 = 0.7034674224983917
#
#
# iteração = 227
# f(x227) = 0.0
# A solução foi encontrada após 226 iterações.
# f`(x227) = 1.901801259513314
# x228 = 0.7034674224983917 - (0.0/1.901801259513314)
# x228 = 0.7034674224983917
#
#
# iteração = 228
# f(x228) = 0.0
# A solução foi encontrada após 227 iterações.
# f`(x228) = 1.901801259513314
# x229 = 0.7034674224983917 - (0.0/1.901801259513314)
# x229 = 0.7034674224983917
#
#
# iteração = 229
# f(x229) = 0.0
# A solução foi encontrada após 228 iterações.
# f`(x229) = 1.901801259513314
# x230 = 0.7034674224983917 - (0.0/1.901801259513314)
# x230 = 0.7034674224983917
#
#
# iteração = 230
# f(x230) = 0.0
# A solução foi encontrada após 229 iterações.
# f`(x230) = 1.901801259513314
# x231 = 0.7034674224983917 - (0.0/1.901801259513314)
# x231 = 0.7034674224983917
#
#
# iteração = 231
# f(x231) = 0.0
# A solução foi encontrada após 230 iterações.
# f`(x231) = 1.901801259513314
# x232 = 0.7034674224983917 - (0.0/1.901801259513314)
# x232 = 0.7034674224983917
#
#
# iteração = 232
# f(x232) = 0.0
# A solução foi encontrada após 231 iterações.
# f`(x232) = 1.901801259513314
# x233 = 0.7034674224983917 - (0.0/1.901801259513314)
# x233 = 0.7034674224983917
#
#
# iteração = 233
# f(x233) = 0.0
# A solução foi encontrada após 232 iterações.
# f`(x233) = 1.901801259513314
# x234 = 0.7034674224983917 - (0.0/1.901801259513314)
# x234 = 0.7034674224983917
#
#
# iteração = 234
# f(x234) = 0.0
# A solução foi encontrada após 233 iterações.
# f`(x234) = 1.901801259513314
# x235 = 0.7034674224983917 - (0.0/1.901801259513314)
# x235 = 0.7034674224983917
#
#
# iteração = 235
# f(x235) = 0.0
# A solução foi encontrada após 234 iterações.
# f`(x235) = 1.901801259513314
# x236 = 0.7034674224983917 - (0.0/1.901801259513314)
# x236 = 0.7034674224983917
#
#
# iteração = 236
# f(x236) = 0.0
# A solução foi encontrada após 235 iterações.
# f`(x236) = 1.901801259513314
# x237 = 0.7034674224983917 - (0.0/1.901801259513314)
# x237 = 0.7034674224983917
#
#
# iteração = 237
# f(x237) = 0.0
# A solução foi encontrada após 236 iterações.
# f`(x237) = 1.901801259513314
# x238 = 0.7034674224983917 - (0.0/1.901801259513314)
# x238 = 0.7034674224983917
#
#
# iteração = 238
# f(x238) = 0.0
# A solução foi encontrada após 237 iterações.
# f`(x238) = 1.901801259513314
# x239 = 0.7034674224983917 - (0.0/1.901801259513314)
# x239 = 0.7034674224983917
#
#
# iteração = 239
# f(x239) = 0.0
# A solução foi encontrada após 238 iterações.
# f`(x239) = 1.901801259513314
# x240 = 0.7034674224983917 - (0.0/1.901801259513314)
# x240 = 0.7034674224983917
#
#
# iteração = 240
# f(x240) = 0.0
# A solução foi encontrada após 239 iterações.
# f`(x240) = 1.901801259513314
# x241 = 0.7034674224983917 - (0.0/1.901801259513314)
# x241 = 0.7034674224983917
#
#
# iteração = 241
# f(x241) = 0.0
# A solução foi encontrada após 240 iterações.
# f`(x241) = 1.901801259513314
# x242 = 0.7034674224983917 - (0.0/1.901801259513314)
# x242 = 0.7034674224983917
#
#
# iteração = 242
# f(x242) = 0.0
# A solução foi encontrada após 241 iterações.
# f`(x242) = 1.901801259513314
# x243 = 0.7034674224983917 - (0.0/1.901801259513314)
# x243 = 0.7034674224983917
#
#
# iteração = 243
# f(x243) = 0.0
# A solução foi encontrada após 242 iterações.
# f`(x243) = 1.901801259513314
# x244 = 0.7034674224983917 - (0.0/1.901801259513314)
# x244 = 0.7034674224983917
#
#
# iteração = 244
# f(x244) = 0.0
# A solução foi encontrada após 243 iterações.
# f`(x244) = 1.901801259513314
# x245 = 0.7034674224983917 - (0.0/1.901801259513314)
# x245 = 0.7034674224983917
#
#
# iteração = 245
# f(x245) = 0.0
# A solução foi encontrada após 244 iterações.
# f`(x245) = 1.901801259513314
# x246 = 0.7034674224983917 - (0.0/1.901801259513314)
# x246 = 0.7034674224983917
#
#
# iteração = 246
# f(x246) = 0.0
# A solução foi encontrada após 245 iterações.
# f`(x246) = 1.901801259513314
# x247 = 0.7034674224983917 - (0.0/1.901801259513314)
# x247 = 0.7034674224983917
#
#
# iteração = 247
# f(x247) = 0.0
# A solução foi encontrada após 246 iterações.
# f`(x247) = 1.901801259513314
# x248 = 0.7034674224983917 - (0.0/1.901801259513314)
# x248 = 0.7034674224983917
#
#
# iteração = 248
# f(x248) = 0.0
# A solução foi encontrada após 247 iterações.
# f`(x248) = 1.901801259513314
# x249 = 0.7034674224983917 - (0.0/1.901801259513314)
# x249 = 0.7034674224983917
#
#
# iteração = 249
# f(x249) = 0.0
# A solução foi encontrada após 248 iterações.
# f`(x249) = 1.901801259513314
# x250 = 0.7034674224983917 - (0.0/1.901801259513314)
# x250 = 0.7034674224983917
#
#
# iteração = 250
# f(x250) = 0.0
# A solução foi encontrada após 249 iterações.
# f`(x250) = 1.901801259513314
# x251 = 0.7034674224983917 - (0.0/1.901801259513314)
# x251 = 0.7034674224983917
#
#
# iteração = 251
# f(x251) = 0.0
# A solução foi encontrada após 250 iterações.
# f`(x251) = 1.901801259513314
# x252 = 0.7034674224983917 - (0.0/1.901801259513314)
# x252 = 0.7034674224983917
#
#
# iteração = 252
# f(x252) = 0.0
# A solução foi encontrada após 251 iterações.
# f`(x252) = 1.901801259513314
# x253 = 0.7034674224983917 - (0.0/1.901801259513314)
# x253 = 0.7034674224983917
#
#
# iteração = 253
# f(x253) = 0.0
# A solução foi encontrada após 252 iterações.
# f`(x253) = 1.901801259513314
# x254 = 0.7034674224983917 - (0.0/1.901801259513314)
# x254 = 0.7034674224983917
#
#
# iteração = 254
# f(x254) = 0.0
# A solução foi encontrada após 253 iterações.
# f`(x254) = 1.901801259513314
# x255 = 0.7034674224983917 - (0.0/1.901801259513314)
# x255 = 0.7034674224983917
#
#
# iteração = 255
# f(x255) = 0.0
# A solução foi encontrada após 254 iterações.
# f`(x255) = 1.901801259513314
# x256 = 0.7034674224983917 - (0.0/1.901801259513314)
# x256 = 0.7034674224983917
#
#
# iteração = 256
# f(x256) = 0.0
# A solução foi encontrada após 255 iterações.
# f`(x256) = 1.901801259513314
# x257 = 0.7034674224983917 - (0.0/1.901801259513314)
# x257 = 0.7034674224983917
#
#
# iteração = 257
# f(x257) = 0.0
# A solução foi encontrada após 256 iterações.
# f`(x257) = 1.901801259513314
# x258 = 0.7034674224983917 - (0.0/1.901801259513314)
# x258 = 0.7034674224983917
#
#
# iteração = 258
# f(x258) = 0.0
# A solução foi encontrada após 257 iterações.
# f`(x258) = 1.901801259513314
# x259 = 0.7034674224983917 - (0.0/1.901801259513314)
# x259 = 0.7034674224983917
#
#
# iteração = 259
# f(x259) = 0.0
# A solução foi encontrada após 258 iterações.
# f`(x259) = 1.901801259513314
# x260 = 0.7034674224983917 - (0.0/1.901801259513314)
# x260 = 0.7034674224983917
#
#
# iteração = 260
# f(x260) = 0.0
# A solução foi encontrada após 259 iterações.
# f`(x260) = 1.901801259513314
# x261 = 0.7034674224983917 - (0.0/1.901801259513314)
# x261 = 0.7034674224983917
#
#
# iteração = 261
# f(x261) = 0.0
# A solução foi encontrada após 260 iterações.
# f`(x261) = 1.901801259513314
# x262 = 0.7034674224983917 - (0.0/1.901801259513314)
# x262 = 0.7034674224983917
#
#
# iteração = 262
# f(x262) = 0.0
# A solução foi encontrada após 261 iterações.
# f`(x262) = 1.901801259513314
# x263 = 0.7034674224983917 - (0.0/1.901801259513314)
# x263 = 0.7034674224983917
#
#
# iteração = 263
# f(x263) = 0.0
# A solução foi encontrada após 262 iterações.
# f`(x263) = 1.901801259513314
# x264 = 0.7034674224983917 - (0.0/1.901801259513314)
# x264 = 0.7034674224983917
#
#
# iteração = 264
# f(x264) = 0.0
# A solução foi encontrada após 263 iterações.
# f`(x264) = 1.901801259513314
# x265 = 0.7034674224983917 - (0.0/1.901801259513314)
# x265 = 0.7034674224983917
#
#
# iteração = 265
# f(x265) = 0.0
# A solução foi encontrada após 264 iterações.
# f`(x265) = 1.901801259513314
# x266 = 0.7034674224983917 - (0.0/1.901801259513314)
# x266 = 0.7034674224983917
#
#
# iteração = 266
# f(x266) = 0.0
# A solução foi encontrada após 265 iterações.
# f`(x266) = 1.901801259513314
# x267 = 0.7034674224983917 - (0.0/1.901801259513314)
# ...
# x9917 = 0.7034674224983917
#
#
# iteração = 9917
# f(x9917) = 0.0
# A solução foi encontrada após 9916 iterações.
# f`(x9917) = 1.901801259513314
# x9918 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9918 = 0.7034674224983917
#
#
# iteração = 9918
# f(x9918) = 0.0
# A solução foi encontrada após 9917 iterações.
# f`(x9918) = 1.901801259513314
# x9919 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9919 = 0.7034674224983917
#
#
# iteração = 9919
# f(x9919) = 0.0
# A solução foi encontrada após 9918 iterações.
# f`(x9919) = 1.901801259513314
# x9920 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9920 = 0.7034674224983917
#
#
# iteração = 9920
# f(x9920) = 0.0
# A solução foi encontrada após 9919 iterações.
# f`(x9920) = 1.901801259513314
# x9921 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9921 = 0.7034674224983917
#
#
# iteração = 9921
# f(x9921) = 0.0
# A solução foi encontrada após 9920 iterações.
# f`(x9921) = 1.901801259513314
# x9922 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9922 = 0.7034674224983917
#
#
# iteração = 9922
# f(x9922) = 0.0
# A solução foi encontrada após 9921 iterações.
# f`(x9922) = 1.901801259513314
# x9923 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9923 = 0.7034674224983917
#
#
# iteração = 9923
# f(x9923) = 0.0
# A solução foi encontrada após 9922 iterações.
# f`(x9923) = 1.901801259513314
# x9924 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9924 = 0.7034674224983917
#
#
# iteração = 9924
# f(x9924) = 0.0
# A solução foi encontrada após 9923 iterações.
# f`(x9924) = 1.901801259513314
# x9925 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9925 = 0.7034674224983917
#
#
# iteração = 9925
# f(x9925) = 0.0
# A solução foi encontrada após 9924 iterações.
# f`(x9925) = 1.901801259513314
# x9926 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9926 = 0.7034674224983917
#
#
# iteração = 9926
# f(x9926) = 0.0
# A solução foi encontrada após 9925 iterações.
# f`(x9926) = 1.901801259513314
# x9927 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9927 = 0.7034674224983917
#
#
# iteração = 9927
# f(x9927) = 0.0
# A solução foi encontrada após 9926 iterações.
# f`(x9927) = 1.901801259513314
# x9928 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9928 = 0.7034674224983917
#
#
# iteração = 9928
# f(x9928) = 0.0
# A solução foi encontrada após 9927 iterações.
# f`(x9928) = 1.901801259513314
# x9929 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9929 = 0.7034674224983917
#
#
# iteração = 9929
# f(x9929) = 0.0
# A solução foi encontrada após 9928 iterações.
# f`(x9929) = 1.901801259513314
# x9930 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9930 = 0.7034674224983917
#
#
# iteração = 9930
# f(x9930) = 0.0
# A solução foi encontrada após 9929 iterações.
# f`(x9930) = 1.901801259513314
# x9931 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9931 = 0.7034674224983917
#
#
# iteração = 9931
# f(x9931) = 0.0
# A solução foi encontrada após 9930 iterações.
# f`(x9931) = 1.901801259513314
# x9932 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9932 = 0.7034674224983917
#
#
# iteração = 9932
# f(x9932) = 0.0
# A solução foi encontrada após 9931 iterações.
# f`(x9932) = 1.901801259513314
# x9933 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9933 = 0.7034674224983917
#
#
# iteração = 9933
# f(x9933) = 0.0
# A solução foi encontrada após 9932 iterações.
# f`(x9933) = 1.901801259513314
# x9934 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9934 = 0.7034674224983917
#
#
# iteração = 9934
# f(x9934) = 0.0
# A solução foi encontrada após 9933 iterações.
# f`(x9934) = 1.901801259513314
# x9935 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9935 = 0.7034674224983917
#
#
# iteração = 9935
# f(x9935) = 0.0
# A solução foi encontrada após 9934 iterações.
# f`(x9935) = 1.901801259513314
# x9936 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9936 = 0.7034674224983917
#
#
# iteração = 9936
# f(x9936) = 0.0
# A solução foi encontrada após 9935 iterações.
# f`(x9936) = 1.901801259513314
# x9937 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9937 = 0.7034674224983917
#
#
# iteração = 9937
# f(x9937) = 0.0
# A solução foi encontrada após 9936 iterações.
# f`(x9937) = 1.901801259513314
# x9938 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9938 = 0.7034674224983917
#
#
# iteração = 9938
# f(x9938) = 0.0
# A solução foi encontrada após 9937 iterações.
# f`(x9938) = 1.901801259513314
# x9939 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9939 = 0.7034674224983917
#
#
# iteração = 9939
# f(x9939) = 0.0
# A solução foi encontrada após 9938 iterações.
# f`(x9939) = 1.901801259513314
# x9940 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9940 = 0.7034674224983917
#
#
# iteração = 9940
# f(x9940) = 0.0
# A solução foi encontrada após 9939 iterações.
# f`(x9940) = 1.901801259513314
# x9941 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9941 = 0.7034674224983917
#
#
# iteração = 9941
# f(x9941) = 0.0
# A solução foi encontrada após 9940 iterações.
# f`(x9941) = 1.901801259513314
# x9942 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9942 = 0.7034674224983917
#
#
# iteração = 9942
# f(x9942) = 0.0
# A solução foi encontrada após 9941 iterações.
# f`(x9942) = 1.901801259513314
# x9943 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9943 = 0.7034674224983917
#
#
# iteração = 9943
# f(x9943) = 0.0
# A solução foi encontrada após 9942 iterações.
# f`(x9943) = 1.901801259513314
# x9944 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9944 = 0.7034674224983917
#
#
# iteração = 9944
# f(x9944) = 0.0
# A solução foi encontrada após 9943 iterações.
# f`(x9944) = 1.901801259513314
# x9945 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9945 = 0.7034674224983917
#
#
# iteração = 9945
# f(x9945) = 0.0
# A solução foi encontrada após 9944 iterações.
# f`(x9945) = 1.901801259513314
# x9946 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9946 = 0.7034674224983917
#
#
# iteração = 9946
# f(x9946) = 0.0
# A solução foi encontrada após 9945 iterações.
# f`(x9946) = 1.901801259513314
# x9947 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9947 = 0.7034674224983917
# iteração = 9947
# f(x9947) = 0.0
# A solução foi encontrada após 9946 iterações.
# f`(x9947) = 1.901801259513314
# x9948 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9948 = 0.7034674224983917
#
#
# iteração = 9948
# f(x9948) = 0.0
# A solução foi encontrada após 9947 iterações.
# f`(x9948) = 1.901801259513314
# x9949 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9949 = 0.7034674224983917
#
#
# iteração = 9949
# f(x9949) = 0.0
# A solução foi encontrada após 9948 iterações.
# f`(x9949) = 1.901801259513314
# x9950 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9950 = 0.7034674224983917
#
#
# iteração = 9950
# f(x9950) = 0.0
# A solução foi encontrada após 9949 iterações.
# f`(x9950) = 1.901801259513314
# x9951 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9951 = 0.7034674224983917
#
#
# iteração = 9951
# f(x9951) = 0.0
# A solução foi encontrada após 9950 iterações.
# f`(x9951) = 1.901801259513314
# x9952 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9952 = 0.7034674224983917
#
#
# iteração = 9952
# f(x9952) = 0.0
# A solução foi encontrada após 9951 iterações.
# f`(x9952) = 1.901801259513314
# x9953 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9953 = 0.7034674224983917
#
#
# iteração = 9953
# f(x9953) = 0.0
# A solução foi encontrada após 9952 iterações.
# f`(x9953) = 1.901801259513314
# x9954 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9954 = 0.7034674224983917
#
#
# iteração = 9954
# f(x9954) = 0.0
# A solução foi encontrada após 9953 iterações.
# f`(x9954) = 1.901801259513314
# x9955 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9955 = 0.7034674224983917
#
#
# iteração = 9955
# f(x9955) = 0.0
# A solução foi encontrada após 9954 iterações.
# f`(x9955) = 1.901801259513314
# x9956 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9956 = 0.7034674224983917
#
#
# iteração = 9956
# f(x9956) = 0.0
# A solução foi encontrada após 9955 iterações.
# f`(x9956) = 1.901801259513314
# x9957 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9957 = 0.7034674224983917
#
#
# iteração = 9957
# f(x9957) = 0.0
# A solução foi encontrada após 9956 iterações.
# f`(x9957) = 1.901801259513314
# x9958 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9958 = 0.7034674224983917
#
#
# iteração = 9958
# f(x9958) = 0.0
# A solução foi encontrada após 9957 iterações.
# f`(x9958) = 1.901801259513314
# x9959 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9959 = 0.7034674224983917
#
#
# iteração = 9959
# f(x9959) = 0.0
# A solução foi encontrada após 9958 iterações.
# f`(x9959) = 1.901801259513314
# x9960 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9960 = 0.7034674224983917
#
#
# iteração = 9960
# f(x9960) = 0.0
# A solução foi encontrada após 9959 iterações.
# f`(x9960) = 1.901801259513314
# x9961 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9961 = 0.7034674224983917
#
#
# iteração = 9961
# f(x9961) = 0.0
# A solução foi encontrada após 9960 iterações.
# f`(x9961) = 1.901801259513314
# x9962 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9962 = 0.7034674224983917
#
#
# iteração = 9962
# f(x9962) = 0.0
# A solução foi encontrada após 9961 iterações.
# f`(x9962) = 1.901801259513314
# x9963 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9963 = 0.7034674224983917
#
#
# iteração = 9963
# f(x9963) = 0.0
# A solução foi encontrada após 9962 iterações.
# f`(x9963) = 1.901801259513314
# x9964 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9964 = 0.7034674224983917
#
#
# iteração = 9964
# f(x9964) = 0.0
# A solução foi encontrada após 9963 iterações.
# f`(x9964) = 1.901801259513314
# x9965 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9965 = 0.7034674224983917
#
#
# iteração = 9965
# f(x9965) = 0.0
# A solução foi encontrada após 9964 iterações.
# f`(x9965) = 1.901801259513314
# x9966 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9966 = 0.7034674224983917
#
#
# iteração = 9966
# f(x9966) = 0.0
# A solução foi encontrada após 9965 iterações.
# f`(x9966) = 1.901801259513314
# x9967 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9967 = 0.7034674224983917
#
#
# iteração = 9967
# f(x9967) = 0.0
# A solução foi encontrada após 9966 iterações.
# f`(x9967) = 1.901801259513314
# x9968 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9968 = 0.7034674224983917
#
#
# iteração = 9968
# f(x9968) = 0.0
# A solução foi encontrada após 9967 iterações.
# f`(x9968) = 1.901801259513314
# x9969 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9969 = 0.7034674224983917
#
#
# iteração = 9969
# f(x9969) = 0.0
# A solução foi encontrada após 9968 iterações.
# f`(x9969) = 1.901801259513314
# x9970 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9970 = 0.7034674224983917
#
#
# iteração = 9970
# f(x9970) = 0.0
# A solução foi encontrada após 9969 iterações.
# f`(x9970) = 1.901801259513314
# x9971 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9971 = 0.7034674224983917
#
#
# iteração = 9971
# f(x9971) = 0.0
# A solução foi encontrada após 9970 iterações.
# f`(x9971) = 1.901801259513314
# x9972 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9972 = 0.7034674224983917
#
#
# iteração = 9972
# f(x9972) = 0.0
# A solução foi encontrada após 9971 iterações.
# f`(x9972) = 1.901801259513314
# x9973 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9973 = 0.7034674224983917
#
#
# iteração = 9973
# f(x9973) = 0.0
# A solução foi encontrada após 9972 iterações.
# f`(x9973) = 1.901801259513314
# x9974 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9974 = 0.7034674224983917
#
#
# iteração = 9974
# f(x9974) = 0.0
# A solução foi encontrada após 9973 iterações.
# f`(x9974) = 1.901801259513314
# x9975 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9975 = 0.7034674224983917
#
#
# iteração = 9975
# f(x9975) = 0.0
# A solução foi encontrada após 9974 iterações.
# f`(x9975) = 1.901801259513314
# x9976 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9976 = 0.7034674224983917
#
#
# iteração = 9976
# f(x9976) = 0.0
# A solução foi encontrada após 9975 iterações.
# f`(x9976) = 1.901801259513314
# x9977 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9977 = 0.7034674224983917
#
#
# iteração = 9977
# f(x9977) = 0.0
# A solução foi encontrada após 9976 iterações.
# f`(x9977) = 1.901801259513314
# x9978 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9978 = 0.7034674224983917
#
#
# iteração = 9978
# f(x9978) = 0.0
# A solução foi encontrada após 9977 iterações.
# f`(x9978) = 1.901801259513314
# x9979 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9979 = 0.7034674224983917
#
#
# iteração = 9979
# f(x9979) = 0.0
# A solução foi encontrada após 9978 iterações.
# f`(x9979) = 1.901801259513314
# x9980 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9980 = 0.7034674224983917
#
#
# iteração = 9980
# f(x9980) = 0.0
# A solução foi encontrada após 9979 iterações.
# f`(x9980) = 1.901801259513314
# x9981 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9981 = 0.7034674224983917
#
#
# iteração = 9981
# f(x9981) = 0.0
# A solução foi encontrada após 9980 iterações.
# f`(x9981) = 1.901801259513314
# x9982 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9982 = 0.7034674224983917
#
#
# iteração = 9982
# f(x9982) = 0.0
# A solução foi encontrada após 9981 iterações.
# f`(x9982) = 1.901801259513314
# x9983 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9983 = 0.7034674224983917
#
#
# iteração = 9983
# f(x9983) = 0.0
# A solução foi encontrada após 9982 iterações.
# f`(x9983) = 1.901801259513314
# x9984 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9984 = 0.7034674224983917
#
#
# iteração = 9984
# f(x9984) = 0.0
# A solução foi encontrada após 9983 iterações.
# f`(x9984) = 1.901801259513314
# x9985 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9985 = 0.7034674224983917
#
#
# iteração = 9985
# f(x9985) = 0.0
# A solução foi encontrada após 9984 iterações.
# f`(x9985) = 1.901801259513314
# x9986 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9986 = 0.7034674224983917
#
#
# iteração = 9986
# f(x9986) = 0.0
# A solução foi encontrada após 9985 iterações.
# f`(x9986) = 1.901801259513314
# x9987 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9987 = 0.7034674224983917
#
#
# iteração = 9987
# f(x9987) = 0.0
# A solução foi encontrada após 9986 iterações.
# f`(x9987) = 1.901801259513314
# x9988 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9988 = 0.7034674224983917
#
#
# iteração = 9988
# f(x9988) = 0.0
# A solução foi encontrada após 9987 iterações.
# f`(x9988) = 1.901801259513314
# x9989 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9989 = 0.7034674224983917
#
#
# iteração = 9989
# f(x9989) = 0.0
# A solução foi encontrada após 9988 iterações.
# f`(x9989) = 1.901801259513314
# x9990 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9990 = 0.7034674224983917
#
#
# iteração = 9990
# f(x9990) = 0.0
# A solução foi encontrada após 9989 iterações.
# f`(x9990) = 1.901801259513314
# x9991 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9991 = 0.7034674224983917
#
#
# iteração = 9991
# f(x9991) = 0.0
# A solução foi encontrada após 9990 iterações.
# f`(x9991) = 1.901801259513314
# x9992 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9992 = 0.7034674224983917
#
#
# iteração = 9992
# f(x9992) = 0.0
# A solução foi encontrada após 9991 iterações.
# f`(x9992) = 1.901801259513314
# x9993 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9993 = 0.7034674224983917
#
#
# iteração = 9993
# f(x9993) = 0.0
# A solução foi encontrada após 9992 iterações.
# f`(x9993) = 1.901801259513314
# x9994 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9994 = 0.7034674224983917
#
#
# iteração = 9994
# f(x9994) = 0.0
# A solução foi encontrada após 9993 iterações.
# f`(x9994) = 1.901801259513314
# x9995 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9995 = 0.7034674224983917
#
#
# iteração = 9995
# f(x9995) = 0.0
# A solução foi encontrada após 9994 iterações.
# f`(x9995) = 1.901801259513314
# x9996 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9996 = 0.7034674224983917
#
#
# iteração = 9996
# f(x9996) = 0.0
# A solução foi encontrada após 9995 iterações.
# f`(x9996) = 1.901801259513314
# x9997 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9997 = 0.7034674224983917
#
#
# iteração = 9997
# f(x9997) = 0.0
# A solução foi encontrada após 9996 iterações.
# f`(x9997) = 1.901801259513314
# x9998 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9998 = 0.7034674224983917
#
#
# iteração = 9998
# f(x9998) = 0.0
# A solução foi encontrada após 9997 iterações.
# f`(x9998) = 1.901801259513314
# x9999 = 0.7034674224983917 - (0.0/1.901801259513314)
# x9999 = 0.7034674224983917
#
#
# iteração = 9999
# f(x9999) = 0.0
# A solução foi encontrada após 9998 iterações.
# f`(x9999) = 1.901801259513314
# x10000 = 0.7034674224983917 - (0.0/1.901801259513314)
# x10000 = 0.7034674224983917
#
#
# iteração = 10000
# f(x10000) = 0.0
# A solução foi encontrada após 9999 iterações.
# f`(x10000) = 1.901801259513314
# x10001 = 0.7034674224983917 - (0.0/1.901801259513314)
# x10001 = 0.7034674224983917
#
#
# Excede o número máximo de iterações. Nenhuma solução encontrada.
# None
